# %%
import pandas as pd

df = pd.read_csv("data/legend_class_geo.csv")
df = df[df["geometry"] == "polygon"]
df.head()
# Out:
#        hex  percentage              class geometry  z
# 0  #fbf8f3   61.622346    area sans build  polygon  1
# 1  #f9f6ef    3.615353   residential area  polygon  2
# 2  #e7e5e1    0.320111  surrounding metro  polygon  3
# 3  #e0ecd3    5.580816              grass  polygon  4
# 4  #e2ecd4    0.303872             grass2  polygon  5

# %%
import os
os.makedirs("output/overlays/poly", exist_ok=True)

# %%
import numpy as np
import cv2
from tqdm import tqdm

img = cv2.imread("data/el_harrach_highres_map.png")
img_i16 = img.astype(np.int16)

tolerance = 1
# overlays = []

for i, row in tqdm(df.iterrows(), total=len(df), desc="Generating overlays"):
    hex_color = row["hex"].lstrip("#")
    rgb = np.array([int(hex_color[i:i+2], 16) for i in (0, 2, 4)], dtype=np.int16)
    bgr = rgb[::-1]  # convert to BGR for OpenCV

    mask = np.all(np.abs(img_i16 - bgr) <= tolerance, axis=2)

    result = img.copy()
    result[mask] = (0, 0, 255)

    # overlays.append(result)

    class_name = row["class"]
    class_name_safe = class_name.replace(" ", "_")

    cv2.imwrite(f"output/overlays/poly/overlay_{i+1}_{class_name_safe}.png", result)
# Out:
# Generating overlays:   0%|                                                                                                                               | 0/7 [00:00<?, ?it/s]
# Generating overlays:  14%|█████████████████                                                                                                      | 1/7 [00:03<00:18,  3.01s/it]
# Generating overlays:  29%|██████████████████████████████████                                                                                     | 2/7 [00:05<00:12,  2.47s/it]
# Generating overlays:  43%|███████████████████████████████████████████████████                                                                    | 3/7 [00:07<00:09,  2.26s/it]
# Generating overlays:  57%|████████████████████████████████████████████████████████████████████                                                   | 4/7 [00:09<00:06,  2.21s/it]
# Generating overlays:  71%|█████████████████████████████████████████████████████████████████████████████████████                                  | 5/7 [00:11<00:04,  2.14s/it]
# Generating overlays:  86%|██████████████████████████████████████████████████████████████████████████████████████████████████████                 | 6/7 [00:13<00:02,  2.12s/it]
# Generating overlays: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 7/7 [00:15<00:00,  2.18s/it]
# Generating overlays: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 7/7 [00:15<00:00,  2.23s/it]
